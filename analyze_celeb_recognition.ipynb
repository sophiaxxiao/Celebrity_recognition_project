# %% [markdown]
# # Analyze Celebrity Recognition Results
# ## In this file, we test AWS's celebrity recognition model on the top 40 Chinese and top 40 Western (from Anglophone countries) celebrity face images.

# %%
import pandas as pd # library for data manipulation
import boto3 # Amazon Web Services (AWS) Software Development Kit (SDK) for Python; used to interact with AWS services, such as S3 (Simple Storage Service),
import json # imports the built-in json module, which provides methods for encoding and decoding JSON data
import s3fs # imports the s3fs library, which is a Python interface to interact with data stored on Amazon S3
import io # imports the built-in io module, which provides the Python interfaces for stream handling.
import os
import subprocess
import re

import numpy as np
from IPython.display import Image as IImage

from PIL import Image, ImageDraw, ExifTags, ImageColor
from matplotlib.pyplot import imshow

# %%
# Initialize rekognition client 
client=boto3.client('rekognition')

# %%
# load csvs for Western and Chinese celebrities

western_celebs_csv = pd.read_csv('/home/ec2-user/SageMaker/Celebrity_recognition_project/western_celebs.csv')
chinese_celebs_csv = pd.read_csv('/home/ec2-user/SageMaker/Celebrity_recognition_project/chinese_celebs.csv')

# %%
def recognize_celebs(bucket_name):
    """
    Recognize celebrities in images containing the specified celebrity name.

    Parameters:
    bucket_name (str): The bucket name (bucket must contain all celebrity images)

    Returns:
    dictionary: 
    
    The function searches for images in a list of file names that contain the specified celebrity name.
    It then uses a recognition service to identify celebrity faces in each image.
    For each image, the recognized celebrity names and matching confidence scores are stored as a tuple 
    If no celebrity matches are found, store (None, 0)
    
    Note:
    - You need to have the 'client' and other required variables set up for this function to work correctly.
    - The function does not include code to visualize each image being compared per iteration. You can add that functionality separately.
    """
    s3 = boto3.client('s3')
    confidence_dict = {}

    # List objects at the root level
    objects = s3.list_objects_v2(Bucket=bucket_name, Delimiter='/')

    # Iterate through each "folder" (common prefix)
    for common_prefix in objects.get('CommonPrefixes', []):
        folder_key = common_prefix['Prefix']
        # Check if folder_key exists in confidence_dict
        if folder_key not in confidence_dict:
            confidence_dict[folder_key] = {}
        # List all objects in the folder
        folder_objects = s3.list_objects_v2(Bucket=bucket_name, Prefix=folder_key)
        pics = folder_objects.get('Contents', [])
        for pic in pics:
            pic_name = pic['Key']
            # Check if pic_key exists in the nested dictionary
            if pic['Key'] not in confidence_dict[folder_key]:
                confidence_dict[folder_key][pic_name] = {}
            response = client.recognize_celebrities(Image={'S3Object':{'Bucket': bucket_name,'Name': pic_name}})
            if 'CelebrityFaces' in response and response['CelebrityFaces'] != []:
                for celebrity in response['CelebrityFaces']:
                    # Access keys you want from the response
                    match_name = celebrity.get('Name')
                    confidence_score = celebrity.get('MatchConfidence')
                    # Process the keys as needed
                    print(f"File: {pic['Key']}, Match Name: {match_name}, Match Confidence: {confidence_score}")  
                    confidence_dict[folder_key][pic_name]['match_name'] = match_name
                    confidence_dict[folder_key][pic_name]['confidence_score'] = confidence_score

            else: 
                print(f'No celebrity matches found for {pic_name}')
                confidence_dict[folder_key][pic_name]['match_name'] = 'None'
                confidence_dict[folder_key][pic_name]['confidence_score'] = 0 
        
    return confidence_dict

# %%
results_chinese_celebs = recognize_celebs('chinese-celebs')
# Out:
#   Huang Bo/Huang Bo_5.jpg: {'match_name': 'Huang Bo', 'confidence_score': 99.69879150390625}
#   Huang Bo/Huang Bo_6.jpg: {'match_name': 'Huang Bo', 'confidence_score': 99.85387420654297}
#   Huang Bo/Huang Bo_7.jpg: {'match_name': 'Huang Bo', 'confidence_score': 99.83141326904297}
#   Huang Bo/Huang Bo_8.jpg: {'match_name': 'Huang Bo', 'confidence_score': 99.89490509033203}
# Huang Xiaoming/:
#   Huang Xiaoming/Huang Xiaoming_48.jpg: {'match_name': 'Huang Xiaoming', 'confidence_score': 98.03577423095703}
#   Huang Xiaoming/Huang Xiaoming_50.jpg: {'match_name': 'Huang Xiaoming', 'confidence_score': 97.53113555908203}
#   Huang Xiaoming/Huang Xiaoming_7.jpg: {'match_name': 'Nie Yuan', 'confidence_score': 90.3873519897461}
#   Huang Xiaoming/Huang Xiaoming_8.jpg: {'match_name': 'Huang Xiaoming', 'confidence_score': 94.38658142089844}
#   Huang Xiaoming/Huang Xiaoming_9.jpg: {'match_name': 'Zhao Zhiwei', 'confidence_score': 92.83426666259766}
# Huang Zitao/:
#   Huang Zitao/Huang Zitao_49.jpg: {'match_name': 'Tao', 'confidence_score': 99.75468444824219}
#   Huang Zitao/Huang Zitao_50.jpg: {'match_name': 'Tao', 'confidence_score': 99.79861450195312}
#   Huang Zitao/Huang Zitao_6.jpg: {'match_name': 'Tao', 'confidence_score': 99.13282775878906}
#   Huang Zitao/Huang Zitao_8.jpg: {'match_name': 'Lin Yi', 'confidence_score': 99.01426696777344}
#   Huang Zitao/Huang Zitao_9.jpg: {'match_name': 'Tao', 'confidence_score': 95.15142059326172}
# Jackie Chan/:
#   Jackie Chan/Jackie Chan_50.jpg: {'match_name': 'Jackie Chan', 'confidence_score': 98.03392791748047}
#   Jackie Chan/Jackie Chan_6.jpg: {'match_name': 'Jackie Chan', 'confidence_score': 95.0182876586914}
#   Jackie Chan/Jackie Chan_7.jpg: {'match_name': 'Jackie Chan', 'confidence_score': 99.8315658569336}
#   Jackie Chan/Jackie Chan_8.jpg: {'match_name': 'Jackie Chan', 'confidence_score': 99.13788604736328}
#   Jackie Chan/Jackie Chan_9.jpg: {'match_name': 'Jackie Chan', 'confidence_score': 99.06260681152344}
# Jay Chou/:
#   Jay Chou/Jay Chou_5.jpg: {'match_name': 'Jay Chou', 'confidence_score': 99.0932846069336}
#   Jay Chou/Jay Chou_6.jpg: {'match_name': 'Jay Chou', 'confidence_score': 98.55561828613281}
#   Jay Chou/Jay Chou_7.jpg: {'match_name': 'Jay Chou', 'confidence_score': 99.32063293457031}
#   Jay Chou/Jay Chou_8.jpg: {'match_name': 'Jay Chou', 'confidence_score': 98.22105407714844}
#   Jay Chou/Jay Chou_9.jpg: {'match_name': 'Jay Chou', 'confidence_score': 96.86602020263672}
# Jia Nailiang/:
#   Jia Nailiang/Jia Nailiang_30.jpg: {'match_name': 'Li Dong-xue', 'confidence_score': 88.6307601928711}
#   Jia Nailiang/Jia Nailiang_44.jpg: {'match_name': 'Jia Nailiang', 'confidence_score': 99.46388244628906}
#   Jia Nailiang/Jia Nailiang_49.jpg: {'match_name': 'Jia Nailiang', 'confidence_score': 93.49879455566406}
#   Jia Nailiang/Jia Nailiang_6.jpg: {'match_name': 'Jia Nailiang', 'confidence_score': 99.05747985839844}
#   Jia Nailiang/Jia Nailiang_9.jpg: {'match_name': 'Jia Nailiang', 'confidence_score': 92.71896362304688}
# Jin Dong/:
#   Jin Dong/Jin Dong_43.jpg: {'match_name': 'Jin Dong', 'confidence_score': 95.74317932128906}
#   Jin Dong/Jin Dong_5.jpg: {'match_name': 'Hu Ge', 'confidence_score': 98.71186828613281}
#   Jin Dong/Jin Dong_6.jpg: {'match_name': 'Jin Dong', 'confidence_score': 96.19792938232422}
#   Jin Dong/Jin Dong_7.jpg: {'match_name': 'Jin Dong', 'confidence_score': 98.38065338134766}
#   Jin Dong/Jin Dong_8.jpg: {'match_name': 'Jin Dong', 'confidence_score': 99.8802490234375}
# Jing Boran/:
#   Jing Boran/Jing Boran_43.jpg: {'match_name': 'Jing Boran', 'confidence_score': 99.12423706054688}
#   Jing Boran/Jing Boran_47.jpg: {'match_name': 'Jing Boran', 'confidence_score': 99.8045883178711}
#   Jing Boran/Jing Boran_6.jpg: {'match_name': 'Jing Boran', 'confidence_score': 99.66130065917969}
#   Jing Boran/Jing Boran_7.jpg: {'match_name': 'Jing Boran', 'confidence_score': 99.52186584472656}
#   Jing Boran/Jing Boran_9.jpg: {'match_name': 'Jing Boran', 'confidence_score': 99.94325256347656}
# Jing Tian/:
#   Jing Tian/Jing Tian_43.jpg: {'match_name': 'Jing Tian', 'confidence_score': 99.82672119140625}
#   Jing Tian/Jing Tian_47.jpg: {'match_name': 'Jing Tian', 'confidence_score': 99.31363677978516}
#   Jing Tian/Jing Tian_48.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Jing Tian/Jing Tian_5.jpg: {'match_name': 'Jing Tian', 'confidence_score': 99.86421203613281}
#   Jing Tian/Jing Tian_6.jpg: {'match_name': 'Jing Tian', 'confidence_score': 99.08300018310547}
# Joe Chen/:
#   Joe Chen/joe_chen_1.jpg: {'match_name': 'Joe Chen', 'confidence_score': 96.28003692626953}
#   Joe Chen/joe_chen_2.jpg: {'match_name': 'Joe Chen', 'confidence_score': 99.9297103881836}
#   Joe Chen/joe_chen_3.jpg: {'match_name': 'Joe Chen', 'confidence_score': 87.92134857177734}
#   Joe Chen/joe_chen_4.jpg: {'match_name': 'Joe Chen', 'confidence_score': 93.8143081665039}
#   Joe Chen/joe_chen_5.jpg: {'match_name': 'Joe Chen', 'confidence_score': 97.95185089111328}
# Kris Wu/:
#   Kris Wu/Kris Wu_5.jpg: {'match_name': 'Kris Wu', 'confidence_score': 95.89061737060547}
#   Kris Wu/Kris Wu_6.jpg: {'match_name': 'Kris Wu', 'confidence_score': 95.79829406738281}
#   Kris Wu/Kris Wu_7.jpg: {'match_name': 'Kris Wu', 'confidence_score': 99.27802276611328}
# Liu Yifei/:
#   Liu Yifei/Liu Yifei_50.jpg: {'match_name': 'Liu Yifei', 'confidence_score': 99.00184631347656}
#   Liu Yifei/Liu Yifei_6.jpg: {'match_name': 'Liu Yifei', 'confidence_score': 84.16263580322266}
#   Liu Yifei/Liu Yifei_7.jpg: {'match_name': 'Liu Yifei', 'confidence_score': 98.45917510986328}
#   Liu Yifei/Liu Yifei_8.jpg: {'match_name': 'Liu Yifei', 'confidence_score': 99.49153137207031}
#   Liu Yifei/Liu Yifei_9.jpg: {'match_name': 'Liu Yifei', 'confidence_score': 98.53270721435547}
# Lu Han/:
#   Lu Han/Lu Han_50.jpg: {'match_name': 'Hou Minghao', 'confidence_score': 96.94670104980469}
#   Lu Han/Lu Han_6.jpg: {'match_name': 'Lu Han', 'confidence_score': 98.8191146850586}
#   Lu Han/Lu Han_7.jpg: {'match_name': 'Lu Han', 'confidence_score': 97.44385528564453}
#   Lu Han/Lu Han_8.jpg: {'match_name': 'Lu Han', 'confidence_score': 98.65650939941406}
#   Lu Han/Lu Han_9.jpg: {'match_name': 'Hou Minghao', 'confidence_score': 98.34526824951172}
# Lu Yi/:
#   Lu Yi/lu_yi_10.jpg: {'match_name': 'Lu Yi', 'confidence_score': 95.61151123046875}
#   Lu Yi/lu_yi_6.jpg: {'match_name': 'Lu Yi', 'confidence_score': 85.27552795410156}
#   Lu Yi/lu_yi_7.jpg: {'match_name': 'Lu Yi', 'confidence_score': 99.14881896972656}
#   Lu Yi/lu_yi_8.jpg: {'match_name': 'Lu Yi', 'confidence_score': 99.38581085205078}
#   Lu Yi/lu_yi_9.jpg: {'match_name': 'Nie Yuan', 'confidence_score': 96.6304702758789}
# Mark Chao/:
#   Mark Chao/Mark Chao_50.jpg: {'match_name': 'Mark Chao', 'confidence_score': 96.78865051269531}
#   Mark Chao/Mark Chao_6.jpg: {'match_name': 'Mark Chao', 'confidence_score': 99.40653228759766}
#   Mark Chao/Mark Chao_7.jpg: {'match_name': 'Mark Chao', 'confidence_score': 99.20941925048828}
#   Mark Chao/Mark Chao_8.jpg: {'match_name': 'Mark Chao', 'confidence_score': 97.69171142578125}
#   Mark Chao/Mark Chao_9.jpg: {'match_name': 'Mark Chao', 'confidence_score': 98.61187744140625}
# Nicky Wu/:
#   Nicky Wu/Nicky Wu_44.jpg: {'match_name': 'Julien Bam', 'confidence_score': 75.02680206298828}
#   Nicky Wu/Nicky Wu_49.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Nicky Wu/Nicky Wu_5.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Nicky Wu/Nicky Wu_6.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Nicky Wu/Nicky Wu_8.jpg: {'match_name': 'None', 'confidence_score': 0}
# Shu Qi/:
#   Shu Qi/Shu Qi_5.jpg: {'match_name': 'Shu Qi', 'confidence_score': 99.94291687011719}
#   Shu Qi/Shu Qi_6.jpg: {'match_name': 'Shu Qi', 'confidence_score': 99.97366333007812}
#   Wu Xiubo/Wu Xiubo_9.jpg: {'match_name': 'Wu Xiubo', 'confidence_score': 99.8872299194336}
# Xue Zhiqian/:
#   Xue Zhiqian/Xue Zhiqian_50.jpg: {'match_name': 'Joker Xue', 'confidence_score': 98.04350280761719}
#   Xue Zhiqian/Xue Zhiqian_6.jpg: {'match_name': 'Joker Xue', 'confidence_score': 98.70169067382812}
#   Xue Zhiqian/Xue Zhiqian_7.jpg: {'match_name': 'Joker Xue', 'confidence_score': 97.02767181396484}
#   Xue Zhiqian/Xue Zhiqian_8.jpg: {'match_name': 'Joker Xue', 'confidence_score': 92.0356674194336}
#   Xue Zhiqian/Xue Zhiqian_9.jpg: {'match_name': 'Joker Xue', 'confidence_score': 90.51293182373047}
# Yang Mi/:
#   Yang Mi/Yang Mi_48.jpg: {'match_name': 'Yang Mi', 'confidence_score': 97.78841400146484}
#   Yang Mi/Yang Mi_49.jpg: {'match_name': 'Zhang Xiyuan', 'confidence_score': 97.6873779296875}
#   Yang Mi/Yang Mi_6.jpg: {'match_name': 'Yang Mi', 'confidence_score': 97.67973327636719}
#   Yang Mi/Yang Mi_7.jpg: {'match_name': 'Yang Mi', 'confidence_score': 98.96424102783203}
#   Yang Mi/Yang Mi_9.jpg: {'match_name': 'Yang Mi', 'confidence_score': 95.31706237792969}
# Yang Yang/:
#   Yang Yang/Yang Yang_49.jpg: {'match_name': 'Yang Yang', 'confidence_score': 99.91014099121094}
#   Yang Yang/Yang Yang_6.jpg: {'match_name': 'Yang Yang', 'confidence_score': 99.91407012939453}
#   Yang Yang/Yang Yang_7.jpg: {'match_name': 'Yang Yang', 'confidence_score': 99.99080657958984}
#   Yang Yang/Yang Yang_8.jpg: {'match_name': 'Yang Yang', 'confidence_score': 99.9552993774414}
#   Yang Yang/Yang Yang_9.jpg: {'match_name': 'Yang Yang', 'confidence_score': 99.9718017578125}
# Zhang Yixing/:
#   Zhang Yixing/Zhang Yixing_50.jpg: {'match_name': 'Yu Menglong', 'confidence_score': 96.74705505371094}
#   Zhang Yixing/Zhang Yixing_6.jpg: {'match_name': 'Lay', 'confidence_score': 99.0147705078125}
#   Zhang Yixing/Zhang Yixing_7.jpg: {'match_name': 'Yu Menglong', 'confidence_score': 97.63590240478516}
#   Zhang Yixing/Zhang Yixing_8.jpg: {'match_name': 'Yu Menglong', 'confidence_score': 94.97598266601562}
#   Zhang Yixing/Zhang Yixing_9.jpg: {'match_name': 'Lay', 'confidence_score': 96.5966796875}
# Zhao Liying/:
#   Zhao Liying/Zhao Liying_49.jpg: {'match_name': 'Zhao Liying', 'confidence_score': 99.92693328857422}
#   Zhao Liying/Zhao Liying_50.jpg: {'match_name': 'Zhao Liying', 'confidence_score': 98.66577911376953}
#   Zhao Liying/Zhao Liying_6.jpg: {'match_name': 'Zhao Liying', 'confidence_score': 99.77428436279297}
#   Zhao Liying/Zhao Liying_7.jpg: {'match_name': 'Zhao Liying', 'confidence_score': 97.15910339355469}
#   Zhao Liying/Zhao Liying_8.jpg: {'match_name': 'Zhao Liying', 'confidence_score': 99.78334045410156}
# Zhao Wei/:
#   Zhao Wei/Zhao Wei_5.jpg: {'match_name': 'Zhao Wei', 'confidence_score': 99.77647399902344}
#   Zhao Wei/Zhao Wei_50.jpg: {'match_name': 'Zhao Wei', 'confidence_score': 91.94144439697266}
#   Zhao Wei/Zhao Wei_7.jpg: {'match_name': 'Zhao Wei', 'confidence_score': 99.78614044189453}
#   Zhao Wei/Zhao Wei_8.jpg: {'match_name': 'Zhao Wei', 'confidence_score': 97.06781005859375}
#   Zhao Wei/Zhao Wei_9.jpg: {'match_name': 'Zhao Wei', 'confidence_score': 99.14131164550781}
# Zheng Shuang/:
#   Zheng Shuang/Zheng Shuang_50.jpg: {'match_name': 'Zheng Shuang', 'confidence_score': 98.5903549194336}
#   Zheng Shuang/Zheng Shuang_6.jpg: {'match_name': 'Zheng Shuang', 'confidence_score': 93.9863052368164}
#   Zheng Shuang/Zheng Shuang_7.jpg: {'match_name': 'Zheng Shuang', 'confidence_score': 97.99315643310547}
#   Zheng Shuang/Zheng Shuang_8.jpg: {'match_name': 'Zheng Shuang', 'confidence_score': 95.11212921142578}
#   Zheng Shuang/Zheng Shuang_9.jpg: {'match_name': 'Zheng Shuang', 'confidence_score': 99.01516723632812}

# %%
# Count how many incorrect, correct scores there are and calculate average confidence 
correct = {}
unidentified = {}
incorrect = {}
avg_correct_confidence = {}
avg_incorrect_confidence = {} 

for celebrity, images in results_chinese_celebs.items():
    celebrity = celebrity.rstrip('//')
    correct[celebrity] = 0
    incorrect[celebrity] = 0
    unidentified[celebrity] = 0
    avg_correct_confidence[celebrity] = 0
    avg_incorrect_confidence[celebrity] = 0
    for image, data in images.items():
        if celebrity in data['match_name']:
            avg_correct_confidence[celebrity] += data['confidence_score']
            correct[celebrity] += 1
        elif ('None' in data['match_name']):
            unidentified[celebrity] += ('None' == data['match_name'])
        else:
            avg_incorrect_confidence[celebrity] += data['confidence_score']
            incorrect[celebrity] += 1
            
    if incorrect[celebrity] != 0:
        avg_incorrect_confidence[celebrity] /= incorrect[celebrity]
    if correct[celebrity] != 0:
        avg_correct_confidence[celebrity] /= correct[celebrity]

# %%
# Convert dictionaries to pandas dataframes

correct = pd.DataFrame(list(correct.items()), columns=['Celebrity', 'correct'])
unidentified = pd.DataFrame(list(unidentified.items()), columns=['Celebrity', 'unidentified'])
incorrect = pd.DataFrame(list(incorrect.items()), columns=['Celebrity', 'incorrect'])
avg_correct_confidence = pd.DataFrame(list(avg_correct_confidence.items()), columns=['Celebrity', 'avg_correct_confidence'])
avg_incorrect_confidence = pd.DataFrame(list(avg_incorrect_confidence.items()), columns=['Celebrity', 'avg_incorrect_confidence'])

# %%
# Merge together dictionaries

chinese_celebs_df = pd.merge(pd.merge(correct, incorrect), unidentified)
df1 = pd.merge(avg_correct_confidence, avg_incorrect_confidence)
chinese_celebs_df = pd.merge(chinese_celebs_df, df1)

# %%
# Data cleaning (replace 0 values with NaN in confidence columns)
chinese_celebs_df['avg_incorrect_confidence'].replace(0., np.NaN, inplace = True)
chinese_celebs_df['avg_correct_confidence'].replace(0., np.NaN, inplace = True)
chinese_celebs_df

# Merge together the original celebrity list csv and the results dataframe
chinese_celebs_df = pd.merge(chinese_celebs_csv, chinese_celebs_df, left_on='Name', right_on='Celebrity', how='inner')

chinese_celebs_df.drop(['Celebrity', 'Rank'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14477/597700708.py in ?()
#       3 chinese_celebs_df['avg_correct_confidence'].replace(0., np.NaN, inplace = True)
#       4 chinese_celebs_df
#       5
#       6 # Merge together the original celebrity list csv and the results dataframe
# ----> 7 chinese_celebs_df = pd.merge(chinese_celebs_csv, chinese_celebs_df, left_on='Name', right_on='Celebrity', how='inner')
#       8
#       9 chinese_celebs_df.drop(['Celebrity', 'Rank'], axis = 1, inplace = True)
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     106     copy: bool = True,
#     107     indicator: bool = False,
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     699         (
#     700             self.left_join_keys,
#     701             self.right_join_keys,
#     702             self.join_names,
# --> 703         ) = self._get_merge_keys()
#     704
#     705         # validate the merge keys dtypes. We may need to coerce
#     706         # to avoid incompatible dtypes
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1158                         # Then we're either Hashable or a wrong-length arraylike,
#    1159                         #  the latter of which will raise
#    1160                         rk = cast(Hashable, rk)
#    1161                         if rk is not None:
# -> 1162                             right_keys.append(right._get_label_or_level_values(rk))
#    1163                         else:
#    1164                             # work-around for merge_asof(right_index=True)
#    1165                             right_keys.append(right.index)
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1846                 .get_level_values(key)  # type: ignore[assignment]
#    1847                 ._values
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#    1853         if values.ndim > 1:
#
# KeyError: 'Celebrity'

# %%
# export results to csv
chinese_celebs_df.to_csv('chinese_celebs_results.csv')

# %% [markdown]
# # Calculate Accuracy

# %%
miss_rate = np.sum(chinese_celebs_df['incorrect']) / (np.sum(chinese_celebs_df['incorrect']) + np.sum(chinese_celebs_df['correct']))
accuracy = 1 - miss_rate
print(f'The percent of Chinese celebrities incorrectly or not identified is: {miss_rate * 100} %')
print(f'The percent of Chinese celebrities correctly identified is: {accuracy * 100} %')
# Out:
# The percent of Chinese celebrities incorrectly or not identified is: 19.11764705882353 %
# The percent of Chinese celebrities correctly identified is: 80.88235294117648 %

# %% [markdown]
# # Repeating the same procedure with Western celebrities:

# %%
# %%capture
western_celeb_results_raw = recognize_celebs('western-celebs')

# %%
# print out the 'western_celeb_results_raw' dictionary in a more readable format

for celebrity, images in western_celeb_results_raw.items():
    print(f"{celebrity}:")
    for image, data in images.items():
        print(f"  {image}: {data}")
# Out:
# Adam Sandler/:
#   Adam Sandler/Adam Sandler_30.jpg: {'match_name': 'Adam Sandler', 'confidence_score': 99.46633911132812}
#   Adam Sandler/Adam Sandler_5.jpg: {'match_name': 'Adam Sandler', 'confidence_score': 99.68639373779297}
#   Adam Sandler/Adam Sandler_6.jpg: {'match_name': 'Adam Sandler', 'confidence_score': 91.56005096435547}
#   Adam Sandler/Adam Sandler_7.jpg: {'match_name': 'Adam Sandler', 'confidence_score': 99.04778289794922}
#   Adam Sandler/Adam Sandler_9.jpg: {'match_name': 'Adam Sandler', 'confidence_score': 89.05445861816406}
# Adele/:
#   Adele/Adele_5.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Adele/Adele_6.jpg: {'match_name': 'Adele', 'confidence_score': 97.05509948730469}
#   Adele/Adele_7.jpg: {'match_name': 'Adele', 'confidence_score': 80.65895080566406}
#   Adele/Adele_8.jpg: {'match_name': 'Ángela Ponce', 'confidence_score': 87.249755859375}
#   Adele/Adele_9.jpg: {'match_name': 'Adele', 'confidence_score': 83.32523345947266}
# Andrew Luck/:
#   Andrew Luck/Andrew Luck_25.jpg: {'match_name': 'Andrew Luck', 'confidence_score': 95.30926513671875}
#   Andrew Luck/Andrew Luck_28.jpg: {'match_name': 'Andrew Luck', 'confidence_score': 99.4290771484375}
#   Andrew Luck/Andrew Luck_29.jpg: {'match_name': 'Andrew Luck', 'confidence_score': 99.49533081054688}
#   Andrew Luck/Andrew Luck_5.jpg: {'match_name': 'Andrew Luck', 'confidence_score': 99.5441665649414}
#   Andrew Luck/Andrew Luck_7.jpg: {'match_name': 'Andrew Luck', 'confidence_score': 99.87777709960938}
# Beyoncé/:
#   Beyoncé/Beyoncé_49.jpg: {'match_name': 'Beyoncé', 'confidence_score': 91.16139221191406}
#   Beyoncé/Beyoncé_5.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Beyoncé/Beyoncé_6.jpg: {'match_name': 'Beyoncé', 'confidence_score': 91.20201110839844}
#   Beyoncé/Beyoncé_7.jpg: {'match_name': 'Beyoncé', 'confidence_score': 95.33322143554688}
#   Beyoncé/Beyoncé_9.jpg: {'match_name': 'Beyoncé', 'confidence_score': 88.93061828613281}
# Bruce Springsteen/:
#   Bruce Springsteen/Bruce Springsteen_26.jpg: {'match_name': 'Bruce Springsteen', 'confidence_score': 90.1174545288086}
#   Bruce Springsteen/Bruce Springsteen_28.jpg: {'match_name': 'Bruce Springsteen', 'confidence_score': 98.72203826904297}
#   Bruce Springsteen/Bruce Springsteen_29.jpg: {'match_name': 'Bruce Springsteen', 'confidence_score': 98.36434936523438}
#   Bruce Springsteen/Bruce Springsteen_6.jpg: {'match_name': 'Bruce Springsteen', 'confidence_score': 97.54144287109375}
#   Bruce Springsteen/Bruce Springsteen_9.jpg: {'match_name': 'Bruce Springsteen', 'confidence_score': 99.18677520751953}
# Chris Rock/:
#   Chris Rock/Chris Rock_28.jpg: {'match_name': 'Chris Rock', 'confidence_score': 92.75149536132812}
#   Chris Rock/Chris Rock_5.jpg: {'match_name': 'Chris Rock', 'confidence_score': 99.1923599243164}
#   Chris Rock/Chris Rock_6.jpg: {'match_name': 'Chris Rock', 'confidence_score': 99.24071502685547}
#   Chris Rock/Chris Rock_7.jpg: {'match_name': 'Chris Rock', 'confidence_score': 99.12874603271484}
#   Chris Rock/Chris Rock_9.jpg: {'match_name': 'Chris Rock', 'confidence_score': 99.33533477783203}
# David Copperfield/:
#   David Copperfield/David Copperfield_25.jpg: {'match_name': 'Dev Patel', 'confidence_score': 95.54704284667969}
#   David Copperfield/David Copperfield_29.jpg: {'match_name': 'None', 'confidence_score': 0}
#   David Copperfield/David Copperfield_5.jpg: {'match_name': 'David Copperfield', 'confidence_score': 99.00086212158203}
#   David Copperfield/David Copperfield_7.jpg: {'match_name': 'David Copperfield', 'confidence_score': 99.89532470703125}
#   David Copperfield/David Copperfield_8.jpg: {'match_name': 'David Copperfield', 'confidence_score': 99.21446228027344}
# Diddy/:
#   Diddy/Diddy_43.jpg: {'match_name': 'Sean Combs', 'confidence_score': 95.59111022949219}
#   Diddy/Diddy_48.jpg: {'match_name': 'Sean Combs', 'confidence_score': 99.96636962890625}
#   Diddy/Diddy_6.jpg: {'match_name': 'Sean Combs', 'confidence_score': 99.7381591796875}
#   Diddy/Diddy_7.jpg: {'match_name': 'Sean Combs', 'confidence_score': 96.00823211669922}
#   Diddy/Diddy_8.jpg: {'match_name': 'Sean Combs', 'confidence_score': 99.72715759277344}
# Dr. Phil McGraw/:
#   Dr. Phil McGraw/Dr. Phil McGraw_29.jpg: {'match_name': 'Phil McGraw', 'confidence_score': 99.98772430419922}
#   Dr. Phil McGraw/Dr. Phil McGraw_6.jpg: {'match_name': 'Phil McGraw', 'confidence_score': 99.643310546875}
#   Dr. Phil McGraw/Dr. Phil McGraw_7.jpg: {'match_name': 'Phil McGraw', 'confidence_score': 99.9365005493164}
#   Dr. Phil McGraw/Dr. Phil McGraw_8.jpg: {'match_name': 'Phil McGraw', 'confidence_score': 99.97408294677734}
#   Dr. Phil McGraw/Dr. Phil McGraw_9.jpg: {'match_name': 'Phil McGraw', 'confidence_score': 99.84562683105469}
# Drake/:
#   Drake/Drake_5.jpg: {'match_name': 'Drake', 'confidence_score': 96.99362182617188}
#   Drake/Drake_50.jpg: {'match_name': 'Drake', 'confidence_score': 97.30248260498047}
#   Drake/Drake_7.jpg: {'match_name': 'Drake', 'confidence_score': 95.53224182128906}
#   Drake/Drake_8.jpg: {'match_name': 'Drake', 'confidence_score': 97.49559783935547}
#   Drake/Drake_9.jpg: {'match_name': 'Drake', 'confidence_score': 95.89627838134766}
# Dwayne Johnson/:
#   Dwayne Johnson/Dwayne Johnson_5.jpg: {'match_name': 'Dwayne Johnson', 'confidence_score': 99.24626159667969}
#   Dwayne Johnson/Dwayne Johnson_6.jpg: {'match_name': 'Dwayne Johnson', 'confidence_score': 99.69711303710938}
#   Dwayne Johnson/Dwayne Johnson_7.jpg: {'match_name': 'Dwayne Johnson', 'confidence_score': 99.77020263671875}
#   Dwayne Johnson/Dwayne Johnson_8.jpg: {'match_name': 'Dwayne Johnson', 'confidence_score': 99.3510513305664}
#   Dwayne Johnson/Dwayne Johnson_9.jpg: {'match_name': 'Dwayne Johnson', 'confidence_score': 99.65739440917969}
# Ellen DeGeneres/:
#   Ellen DeGeneres/Ellen DeGeneres_5.jpg: {'match_name': 'Ellen DeGeneres', 'confidence_score': 99.8979721069336}
#   Ellen DeGeneres/Ellen DeGeneres_6.jpg: {'match_name': 'Ellen DeGeneres', 'confidence_score': 98.96527862548828}
#   Ellen DeGeneres/Ellen DeGeneres_7.jpg: {'match_name': 'Ellen DeGeneres', 'confidence_score': 97.82530975341797}
#   Ellen DeGeneres/Ellen DeGeneres_8.jpg: {'match_name': 'Ellen DeGeneres', 'confidence_score': 99.16858673095703}
#   Ellen DeGeneres/Ellen DeGeneres_9.jpg: {'match_name': 'Ellen DeGeneres', 'confidence_score': 95.89517974853516}
# Elton John/:
#   Elton John/Elton John_29.jpg: {'match_name': 'Elton John', 'confidence_score': 99.51603698730469}
#   Elton John/Elton John_30.jpg: {'match_name': 'Elton John', 'confidence_score': 99.78791046142578}
#   Elton John/Elton John_5.jpg: {'match_name': 'Elton John', 'confidence_score': 96.34574890136719}
#   Elton John/Elton John_6.jpg: {'match_name': 'Elton John', 'confidence_score': 96.21829986572266}
#   Elton John/Elton John_8.jpg: {'match_name': 'Elton John', 'confidence_score': 98.31763458251953}
# Garth Brooks/:
#   Garth Brooks/Garth Brooks_29.jpg: {'match_name': 'Garth Brooks', 'confidence_score': 99.95799255371094}
#   Garth Brooks/Garth Brooks_30.jpg: {'match_name': 'Garth Brooks', 'confidence_score': 99.03416442871094}
#   Garth Brooks/Garth Brooks_5.jpg: {'match_name': 'Garth Brooks', 'confidence_score': 96.94874572753906}
#   Garth Brooks/Garth Brooks_6.jpg: {'match_name': 'Garth Brooks', 'confidence_score': 99.96643829345703}
#   Garth Brooks/Garth Brooks_9.jpg: {'match_name': 'Garth Brooks', 'confidence_score': 98.023193359375}
# Gordon Ramsay/:
#   Gordon Ramsay/Gordon Ramsay_30.jpg: {'match_name': 'Gordon Ramsay', 'confidence_score': 99.21837615966797}
#   Gordon Ramsay/Gordon Ramsay_5.jpg: {'match_name': 'Gordon Ramsay', 'confidence_score': 99.53775787353516}
#   Gordon Ramsay/Gordon Ramsay_6.jpg: {'match_name': 'Gordon Ramsay', 'confidence_score': 99.38958740234375}
#   Gordon Ramsay/Gordon Ramsay_7.jpg: {'match_name': 'Gordon Ramsay', 'confidence_score': 99.42388916015625}
#   Gordon Ramsay/Gordon Ramsay_8.jpg: {'match_name': 'Gordon Ramsay', 'confidence_score': 99.87700653076172}
# Howard Stern/:
#   Howard Stern/Howard Stern_47.jpg: {'match_name': 'Howard Stern', 'confidence_score': 99.97296142578125}
#   Howard Stern/Howard Stern_5.jpg: {'match_name': 'Howard Stern', 'confidence_score': 99.9738540649414}
#   Howard Stern/Howard Stern_7.jpg: {'match_name': 'Howard Stern', 'confidence_score': 99.9482421875}
#   Howard Stern/Howard Stern_8.jpg: {'match_name': 'Howard Stern', 'confidence_score': 99.93714904785156}
#   Howard Stern/Howard Stern_9.jpg: {'match_name': 'Howard Stern', 'confidence_score': 99.92621612548828}
# J.K. Rowling/:
#   J.K. Rowling/J.K. Rowling_47.jpg: {'match_name': 'J. K. Rowling', 'confidence_score': 99.25184631347656}
#   J.K. Rowling/J.K. Rowling_48.jpg: {'match_name': 'J. K. Rowling', 'confidence_score': 99.49259185791016}
#   J.K. Rowling/J.K. Rowling_5.jpg: {'match_name': 'J. K. Rowling', 'confidence_score': 99.0631103515625}
#   J.K. Rowling/J.K. Rowling_6.jpg: {'match_name': 'J. K. Rowling', 'confidence_score': 98.50733184814453}
#   J.K. Rowling/J.K. Rowling_7.jpg: {'match_name': 'J. K. Rowling', 'confidence_score': 99.26520538330078}
# James Patterson/:
#   James Patterson/James Patterson_50.jpg: {'match_name': 'James Patterson', 'confidence_score': 99.05762481689453}
#   James Patterson/James Patterson_6.jpg: {'match_name': 'James Patterson', 'confidence_score': 99.49018859863281}
#   James Patterson/James Patterson_7.jpg: {'match_name': 'James Patterson', 'confidence_score': 99.49952697753906}
#   James Patterson/James Patterson_8.jpg: {'match_name': 'James Patterson', 'confidence_score': 99.68635559082031}
#   James Patterson/James Patterson_9.jpg: {'match_name': 'James Patterson', 'confidence_score': 99.92752838134766}
# Jerry Seinfeld/:
#   Jerry Seinfeld/Jerry Seinfeld_5.jpg: {'match_name': 'Jerry Seinfeld', 'confidence_score': 99.69606018066406}
#   Jerry Seinfeld/Jerry Seinfeld_6.jpg: {'match_name': 'Jerry Seinfeld', 'confidence_score': 99.9141845703125}
#   Jerry Seinfeld/Jerry Seinfeld_7.jpg: {'match_name': 'Colin Farrell', 'confidence_score': 99.86239624023438}
#   Jerry Seinfeld/Jerry Seinfeld_8.jpg: {'match_name': 'Colin Farrell', 'confidence_score': 99.80908966064453}
#   Jerry Seinfeld/Jerry Seinfeld_9.jpg: {'match_name': 'Jerry Seinfeld', 'confidence_score': 99.60169982910156}
# Jimmy Buffett/:
#   Jimmy Buffett/Jimmy Buffett_5.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Jimmy Buffett/Jimmy Buffett_6.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Jimmy Buffett/Jimmy Buffett_7.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Jimmy Buffett/Jimmy Buffett_8.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Jimmy Buffett/Jimmy Buffett_9.jpg: {'match_name': 'None', 'confidence_score': 0}
# Justin Bieber/:
#   Justin Bieber/Justin Bieber_5.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Justin Bieber/Justin Bieber_50.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Justin Bieber/Justin Bieber_7.jpg: {'match_name': 'None', 'confidence_score': 0}
#   Justin Bieber/Justin Bieber_8.jpg: {'match_name': 'Justin Bieber', 'confidence_score': 78.26498413085938}
#   Justin Bieber/Justin Bieber_9.jpg: {'match_name': 'None', 'confidence_score': 0}
# Kevin Durant/:
#   Kevin Durant/Kevin Durant_27.jpg: {'match_name': 'Kevin Durant', 'confidence_score': 99.85393524169922}
#   Kevin Durant/Kevin Durant_28.jpg: {'match_name': 'Kevin Durant', 'confidence_score': 99.95530700683594}
#   Kevin Durant/Kevin Durant_5.jpg: {'match_name': 'Kevin Durant', 'confidence_score': 98.72938537597656}
#   Kevin Durant/Kevin Durant_6.jpg: {'match_name': 'Kevin Durant', 'confidence_score': 99.9758071899414}
#   Kevin Durant/Kevin Durant_9.jpg: {'match_name': 'Kevin Durant', 'confidence_score': 99.01585388183594}
# LeBron James/:
#   LeBron James/LeBron James_25.jpg: {'match_name': 'LeBron James', 'confidence_score': 99.9325180053711}
#   LeBron James/LeBron James_28.jpg: {'match_name': 'LeBron James', 'confidence_score': 99.93643188476562}
#   LeBron James/LeBron James_29.jpg: {'match_name': 'LeBron James', 'confidence_score': 99.7631607055664}
#   LeBron James/LeBron James_6.jpg: {'match_name': 'LeBron James', 'confidence_score': 98.02901458740234}
#   LeBron James/LeBron James_7.jpg: {'match_name': 'LeBron James', 'confidence_score': 99.59286499023438}
# Louis C.K./:
#   Louis C.K./Louis C.K._5.jpg: {'match_name': 'Louis C.K.', 'confidence_score': 99.65587615966797}
#   Louis C.K./Louis C.K._6.jpg: {'match_name': 'Louis C.K.', 'confidence_score': 99.39679718017578}
#   Louis C.K./Louis C.K._7.jpg: {'match_name': 'Louis C.K.', 'confidence_score': 99.8965072631836}
#   Louis C.K./Louis C.K._8.jpg: {'match_name': 'Louis C.K.', 'confidence_score': 99.65587615966797}
#   Louis C.K./Louis C.K._9.jpg: {'match_name': 'Louis C.K.', 'confidence_score': 99.3572769165039}
# Mark Wahlberg/:
#   Mark Wahlberg/Mark Wahlberg_27.jpg: {'match_name': 'Mark Wahlberg', 'confidence_score': 99.4453125}
#   Mark Wahlberg/Mark Wahlberg_28.jpg: {'match_name': 'Mark Wahlberg', 'confidence_score': 98.43170928955078}
#   Mark Wahlberg/Mark Wahlberg_5.jpg: {'match_name': 'Mark Wahlberg', 'confidence_score': 99.00190734863281}
#   Mark Wahlberg/Mark Wahlberg_7.jpg: {'match_name': 'Mark Wahlberg', 'confidence_score': 99.32987213134766}
#   Mark Wahlberg/Mark Wahlberg_8.jpg: {'match_name': 'Mark Wahlberg', 'confidence_score': 83.46670532226562}
# Paul McCartney/:
#   Paul McCartney/Paul McCartney_5.jpg: {'match_name': 'Paul McCartney', 'confidence_score': 99.86717987060547}
#   Paul McCartney/Paul McCartney_6.jpg: {'match_name': 'Paul McCartney', 'confidence_score': 99.37847900390625}
#   Paul McCartney/Paul McCartney_7.jpg: {'match_name': 'Paul McCartney', 'confidence_score': 99.96807861328125}
#   Paul McCartney/Paul McCartney_8.jpg: {'match_name': 'Paul McCartney', 'confidence_score': 99.92921447753906}
#   Paul McCartney/Paul McCartney_9.jpg: {'match_name': 'Paul McCartney', 'confidence_score': 99.85627746582031}
# Ryan Seacrest/:
#   Ryan Seacrest/Ryan Seacrest_28.jpg: {'match_name': 'Ryan Seacrest', 'confidence_score': 99.35636138916016}
#   Ryan Seacrest/Ryan Seacrest_5.jpg: {'match_name': 'Ryan Seacrest', 'confidence_score': 99.4456787109375}
#   Ryan Seacrest/Ryan Seacrest_6.jpg: {'match_name': 'Ryan Seacrest', 'confidence_score': 99.8887939453125}
#   Ryan Seacrest/Ryan Seacrest_7.jpg: {'match_name': 'Ryan Seacrest', 'confidence_score': 99.94205474853516}
#   Ryan Seacrest/Ryan Seacrest_8.jpg: {'match_name': 'Ryan Seacrest', 'confidence_score': 99.97325134277344}
# The Weeknd/:
#   The Weeknd/The Weeknd_50.jpg: {'match_name': 'The Weeknd', 'confidence_score': 96.92829132080078}
#   The Weeknd/The Weeknd_6.jpg: {'match_name': 'The Weeknd', 'confidence_score': 99.75584411621094}
#   The Weeknd/The Weeknd_7.jpg: {'match_name': 'None', 'confidence_score': 0}
#   The Weeknd/The Weeknd_8.jpg: {'match_name': 'The Weeknd', 'confidence_score': 99.89271545410156}
#   The Weeknd/The Weeknd_9.jpg: {'match_name': 'The Weeknd', 'confidence_score': 98.92711639404297}
# Vin Diesel/:
#   Vin Diesel/Vin Diesel_5.jpg: {'match_name': 'Vin Diesel', 'confidence_score': 99.77630615234375}
#   Vin Diesel/Vin Diesel_6.jpg: {'match_name': 'Vin Diesel', 'confidence_score': 99.73307800292969}
#   Vin Diesel/Vin Diesel_7.jpg: {'match_name': 'Vin Diesel', 'confidence_score': 99.76001739501953}
#   Vin Diesel/Vin Diesel_8.jpg: {'match_name': 'Vin Diesel', 'confidence_score': 98.9148941040039}
#   Vin Diesel/Vin Diesel_9.jpg: {'match_name': 'Vin Diesel', 'confidence_score': 98.82122802734375}

# %%
# Count how many incorrect, correct scores there are and calculate average confidence 
correct = {}
unidentified = {}
incorrect = {}
avg_correct_confidence = {}
avg_incorrect_confidence = {} 

for celebrity, images in western_celeb_results_raw.items():
    celebrity = celebrity.rstrip('//')
    correct[celebrity] = 0
    incorrect[celebrity] = 0
    unidentified[celebrity] = 0
    avg_correct_confidence[celebrity] = 0
    avg_incorrect_confidence[celebrity] = 0
    for image, data in images.items():
        if celebrity in data['match_name']:
            avg_correct_confidence[celebrity] += data['confidence_score']
            correct[celebrity] += 1
        elif ('None' in data['match_name']):
            unidentified[celebrity] += ('None' == data['match_name'])
        else:
            avg_incorrect_confidence[celebrity] += data['confidence_score']
            incorrect[celebrity] += 1
            
    if incorrect[celebrity] != 0:
        avg_incorrect_confidence[celebrity] /= incorrect[celebrity]
    if correct[celebrity] != 0:
        avg_correct_confidence[celebrity] /= correct[celebrity]

# %%
# Convert dictionaries to pandas dataframes

correct = pd.DataFrame(list(correct.items()), columns=['Celebrity', 'correct'])
unidentified = pd.DataFrame(list(unidentified.items()), columns=['Celebrity', 'unidentified'])
incorrect = pd.DataFrame(list(incorrect.items()), columns=['Celebrity', 'incorrect'])
avg_correct_confidence = pd.DataFrame(list(avg_correct_confidence.items()), columns=['Celebrity', 'avg_correct_confidence'])
avg_incorrect_confidence = pd.DataFrame(list(avg_incorrect_confidence.items()), columns=['Celebrity', 'avg_incorrect_confidence'])

# %%
# Merge together dictionaries

western_celebs_df = pd.merge(pd.merge(correct, incorrect), unidentified)
df1 = pd.merge(avg_correct_confidence, avg_incorrect_confidence)
western_celebs_df = pd.merge(western_celebs_df, df1)

# %%
# Data cleaning (replace 0 values with NaN in confidence columns)
western_celebs_df['avg_incorrect_confidence'].replace(0., np.NaN, inplace = True)
western_celebs_df['avg_correct_confidence'].replace(0., np.NaN, inplace = True)

# Merge together the original celebrity list csv and the results dataframe
western_celebs_df = pd.merge(western_celebs_csv, western_celebs_df, left_on='Name', right_on='Celebrity', how='inner')

western_celebs_df.drop(['Celebrity', 'Rank'], axis = 1, inplace = True)

# export results to csv
western_celebs_df.to_csv('western_celebs_results.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14477/1082281373.py in ?()
#       2 western_celebs_df['avg_incorrect_confidence'].replace(0., np.NaN, inplace = True)
#       3 western_celebs_df['avg_correct_confidence'].replace(0., np.NaN, inplace = True)
#       4
#       5 # Merge together the original celebrity list csv and the results dataframe
# ----> 6 western_celebs_df = pd.merge(western_celebs_csv, western_celebs_df, left_on='Name', right_on='Celebrity', how='inner')
#       7
#       8 western_celebs_df.drop(['Celebrity', 'Rank'], axis = 1, inplace = True)
#       9
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     106     copy: bool = True,
#     107     indicator: bool = False,
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     699         (
#     700             self.left_join_keys,
#     701             self.right_join_keys,
#     702             self.join_names,
# --> 703         ) = self._get_merge_keys()
#     704
#     705         # validate the merge keys dtypes. We may need to coerce
#     706         # to avoid incompatible dtypes
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1158                         # Then we're either Hashable or a wrong-length arraylike,
#    1159                         #  the latter of which will raise
#    1160                         rk = cast(Hashable, rk)
#    1161                         if rk is not None:
# -> 1162                             right_keys.append(right._get_label_or_level_values(rk))
#    1163                         else:
#    1164                             # work-around for merge_asof(right_index=True)
#    1165                             right_keys.append(right.index)
#
# ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1846                 .get_level_values(key)  # type: ignore[assignment]
#    1847                 ._values
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#    1853         if values.ndim > 1:
#
# KeyError: 'Celebrity'

# %%
western_celebs_df
# Out:
#                  Name       Earnings   Occupation  Country  correct  \
# 0               Diddy   $130 million     Musician     U.S.        0
# 1             Beyoncé   $105 million     Musician     U.S.        4
# 2        J.K. Rowling    $95 million       Author     U.K.        0
# 3               Drake    $94 million     Musician   Canada        5
# 4          The Weeknd    $92 million     Musician   Canada        4
# 5        Howard Stern    $90 million  Personality     U.S.        5
# 6     James Patterson    $87 million       Author     U.S.        5
# 7        LeBron James    $86 million      Athlete     U.S.        5
# 8       Justin Bieber  $83.5 million     Musician   Canada        1
# 9     Dr. Phil McGraw    $79 million  Personality     U.S.        0
# 10    Ellen DeGeneres    $77 million  Personality     U.S.        5
# 11  Bruce Springsteen    $75 million     Musician     U.S.        5
# 12              Adele    $69 million     Musician     U.K.        3
# 13     Jerry Seinfeld    $69 million     Comedian     U.S.        3
# 14      Mark Wahlberg    $68 million        Actor     U.S.        5
# 15     Dwayne Johnson    $65 million        Actor     U.S.        5
# 16  David Copperfield  $61.5 million     Magician     U.S.        3
# 17       Kevin Durant  $60.6 million      Athlete     U.S.        5
# 18       Garth Brooks    $60 million     Musician     U.S.        5
# 19         Elton John    $60 million     Musician     U.K.        5
# 20      Gordon Ramsay    $60 million  Personality     U.K.        5
# 21      Ryan Seacrest    $58 million  Personality     U.S.        5
# 22         Chris Rock    $57 million     Comedian     U.S.        5
# 23         Vin Diesel  $54.5 million        Actor     U.S.        5
# 24     Paul McCartney    $54 million     Musician     U.K.        5
# 25         Louis C.K.    $52 million     Comedian     U.S.        5
# 26      Jimmy Buffett  $50.5 million     Musician     U.S.        0
# 27       Adam Sandler  $50.5 million        Actor     U.S.        5
# 28        Andrew Luck    $50 million      Athlete     U.S.        5
#
#     incorrect  unidentified  avg_correct_confidence  avg_incorrect_confidence
# 0           5             0                     NaN                 98.206206
# 1           0             1               91.656811                       NaN
# 2           5             0                     NaN                 99.116017
# 3           0             0               96.644044                       NaN
# 4           0             1               98.875992                       NaN
# 5           0             0               99.951685                       NaN
# 6           0             0               99.532245                       NaN
# 7           0             0               99.450798                       NaN
# 8           0             4               78.264984                       NaN
# 9           5             0                     NaN                 99.877449
# 10          0             0               98.350465                       NaN
# 11          0             0               96.786412                       NaN
# 12          1             1               87.013095                 87.249756
# 13          2             0               99.737315                 99.835743
# 14          0             0               95.935101                       NaN
# 15          0             0               99.544405                       NaN
# 16          1             1               99.370216                 95.547043
# 17          0             0               99.506058                       NaN
# 18          0             0               98.786107                       NaN
# 19          0             0               98.037126                       NaN
# 20          0             0               99.489323                       NaN
# 21          0             0               99.721228                       NaN
# 22          0             0               97.929730                       NaN
# 23          0             0               99.401105                       NaN
# 24          0             0               99.799846                       NaN
# 25          0             0               99.592467                       NaN
# 26          0             5                     NaN                       NaN
# 27          0             0               95.763005                       NaN
# 28          0             0               98.731123                       NaN

# %% [markdown]
# # Calculate Accuracy

# %%
miss_rate = np.sum(western_celebs_df['incorrect']) / (np.sum(western_celebs_df['incorrect']) + np.sum(western_celebs_df['correct']))
accuracy = 1 - miss_rate
print(f'The percent of Western celebrities incorrectly or not identified is: {miss_rate * 100} %')
print(f'The percent of Western celebrities correctly identified is: {accuracy * 100} %')
# Out:
# The percent of Western celebrities incorrectly or not identified is: 14.393939393939394 %
# The percent of Western celebrities correctly identified is: 85.60606060606061 %
